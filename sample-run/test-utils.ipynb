# %%
import utils

# %%
print(utils.get_film_year_release('The Empire Strikes Back'))
print(get_film_year_release ())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(utils.get_film_year_release('The Empire Strikes Back'))
#       2 print(get_film_year_release ())
#       3 utils.sales_total_revenue ()
#
# TypeError: get_film_year_release() takes 0 positional arguments but 1 was given

# %%
utils.sales_total_revenue ()
utils.sales_revenue_by_rep ('brandonwolf@example.com')
utils.poseters_sold_by_rep ('brandonwolf@example.com')
utils.get_most_used_promo_code ( )
utils.get_most_used_promo_code ( )
utils.poster_qty_sold_by_rep ('brandonwolf@example.com')
utils.get_most_sold_poster_content ( )
utils.get_top10_salesrep_by_poster_qty ( )
utils.get_top10_salesrep_by_revenue  ( )
utils.get_top10_posters_by_revenue  ( )
utils.get_top10_posters_by_sales_qty  ( )
utils.get_top10_promo_code_by_sales  ( )
utils.get_promo_code_and_sales_qty  ( )
utils.get_promo_code_and_revenue  ( )
utils.get_order_most_appearing_starship () 
utils.get_order_film_by_most_used_starship ( )
utils.get_all_starships_appear_in_a_movie  ('Attack of the Clones')
utils.get_all_films_starship_appear ('Millennium Falcon')
utils.get_polupar_films_ordered_by_posters_sold ( )
# Out:
#                  film_name  total_quantity
# 0      Revenge of the Sith          194227
# 1       Return of the Jedi          180169
# 2     Attack of the Clones          165072
# 3  The Empire Strikes Back          140748
# 4               A New Hope          133069
# 5       The Phantom Menace           89230

# %%
print(utils.sales_total_revenue ())
print(utils.sales_revenue_by_rep ('brandonwolf@example.com'))
print(utils.poseters_sold_by_rep ('brandonwolf@example.com'))
print(utils.get_most_used_promo_code ( ))
print(utils.get_most_used_promo_code ( ))
print(utils.poster_qty_sold_by_rep ('brandonwolf@example.com'))
print(utils.get_most_sold_poster_content ( ))
print(utils.get_top10_salesrep_by_poster_qty ( ))
print(utils.get_top10_salesrep_by_revenue  ( ))
print(utils.get_top10_posters_by_revenue  ( ))
print(utils.get_top10_posters_by_sales_qty  ( ))
print(utils.get_top10_promo_code_by_sales  ( ))
print(utils.get_promo_code_and_sales_qty  ( ))
print(utils.get_promo_code_and_revenue  ( ))
print(utils.get_order_most_appearing_starship ()) 
print(utils.get_order_film_by_most_used_starship ( ))
print(utils.get_all_starships_appear_in_a_movie  ('Attack of the Clones'))
print(utils.get_all_films_starship_appear ('Millennium Falcon'))
print(utils.get_polupar_films_ordered_by_posters_sold ( ))
# Out:
#    total_revenue
# 0     29259908.0
#    revenue
# 0    850.0
#              poster_content
# 0  AA-9 Coruscant freighter
#    promo_code
# 0  youtube ad
#    promo_code
# 0  youtube ad
#    total_qty
# 0         12
#                  poster_content  total_qty
# 0  Sentinel-class landing craft      25850
#                        sales_rep  total_qty
# 0             vsmith@example.com       2219
# 1              sdunn@example.com       1992
# 2         lewisbryan@example.com       1986
# 3  rodriguezjennifer@example.org       1964
# 4          krystal99@example.com       1958
# 5             noah48@example.org       1952
# 6        jamesbrewer@example.org       1942
# 7          cooperamy@example.com       1940
# 8            mkeller@example.com       1936
# 9             erin97@example.net       1936
#                  sales_rep  total_revenue
# 0        sdunn@example.com       194539.0
# 1   flemingamy@example.org       179361.0
# 2       aprice@example.com       167843.0
# ...

# %%
print(utils.get_all_starships_appear_in_a_movie  ('Attack of the Clones'))
# Out:
#               starship_name
# 0                   Slave 1
# 1        Droid control ship
# 2             Naboo fighter
# 3   J-type diplomatic barge
# 4  AA-9 Coruscant freighter
# 5          Jedi starfighter
# 6       H-type Nubian yacht
# 7     Republic Assault ship
# 8              Solar Sailer

# %%
print(utils.get_top10_promo_code_by_sales  ( ))
# Out:
#                            promo_code  total_count
# 0                          youtube ad           81
# 1                          X link add           73
# 2             Exclusive social offers           70
# 3             Newsletter signup offer           70
# 4                 Free shipping codes           70
# 5  Discount codes for online shopping           69
# 6           Flash sale discount codes           68
# 7                               TV ad           66
# 8              Holiday-specific codes           65
# 9                      Referral codes           63
# Error: (psycopg2.OperationalError) connection to server at "pg-20d77a1a-samplesource.e.aivencloud.com" (159.89.49.226), port 26689 failed: FATAL:  remaining connection slots are reserved for roles with the SUPERUSER attribute
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# None
# ...

# %%
print(utils.get_promo_code_and_sales_qty  ( ))
print(utils.get_promo_code_and_revenue  ( ))
print(utils.get_order_most_appearing_starship ()) 
print(utils.get_order_film_by_most_used_starship ( ))
# Out:
#                             promo_code  total_qty
# 0                           X link add      37479
# 1                                TV ad      36249
# 2               Holiday-specific codes      36005
# 3                           youtube ad      35781
# 4          Abandoned cart coupon codes      34309
# 5              Newsletter signup offer      33580
# 6              Exclusive social offers      32652
# 7                  Free shipping codes      32503
# 8                       Referral codes      31710
# 9                                Radio      30875
# 10           Flash sale discount codes      30085
# 11                    Bundle discounts      28645
# 12               Loyalty program deals      27918
# 13  Discount codes for online shopping      27596
# 14                Influencer discounts      26668
# 15                         Facdbook Ad      26409
# 16            First purchase discounts      25701
# 17     Minimum purchase discount codes      22509
# ...

# %%
print(utils.get_order_film_by_most_used_starship ( ))
# Out:
#                  film_name  starship_count
# 0       Return of the Jedi              12
# 1      Revenge of the Sith              12
# 2     Attack of the Clones               9
# 3  The Empire Strikes Back               9
# 4               A New Hope               8
# 5       The Phantom Menace               5
